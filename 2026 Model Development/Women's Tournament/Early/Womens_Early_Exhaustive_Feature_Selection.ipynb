# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report
from itertools import combinations
import pickle

# Load data
print("Loading data...")
df = pd.read_csv('games_early.csv')

print(f"\nTotal samples in dataset: {len(df)}")
df_filtered = df.copy()
print(f"Samples: {len(df_filtered)}")

# Candidate features
features = [
    'wab',
    'barthag',
    'adj_oe',
    'adj_de',
    'efg_pct',
    'efgd_pct',
    'tor',
    'tord',
    'orb_pct',
    'drb_pct',
    'ftr',
    'ftrd',
    '2p_pct',
    '2pd_pct',
    '3p_pct',
    '3pd_pct',
    '3pr',
    '3prd',
    'adj_tempo'
]

# Check if features exist
missing = [f for f in features if f not in df_filtered.columns]
if missing:
    print(f"\n Warning: Missing features: {missing}")
    features = [f for f in candidate_features if f in df_filtered.columns]

print(f"\nUsing {len(features)} candidate features")

# Prepare data
X = df_filtered[features].copy()
y = df_filtered['win'].copy()

# Handle missing values
print(f"Missing values: {X.isnull().sum().sum()}")
X = X.fillna(X.median())

# Train/test split (40 train, 20 test)
print("\n" + "="*70)
print("TRAIN/TEST SPLIT")
print("="*70)
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=.30, random_state=42, stratify=y
)
print(f"Training samples: {len(X_train)}")
print(f"Test samples: {len(X_test)}")
# Out:
# Loading data...
#
# Total samples in dataset: 480
# Samples: 480
#
# Using 19 candidate features
# Missing values: 0
#
# ======================================================================
# TRAIN/TEST SPLIT
# ======================================================================
# Training samples: 336
# Test samples: 144

# %%
# Standardize
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
print("\n" + "="*70)
print("EXHAUSTIVE FEATURE SELECTION")
print("="*70)
print(f"\nStarting with {len(features)} features")
print(f"Total combinations to evaluate: {sum([len(list(combinations(range(len(features)), i))) for i in range(1, len(features)+1)]):,}")

# Store results
best_score = 0
best_features = None
best_n_features = 0
all_results = []

# Try all possible feature combinations from size 1 to 25
for n_features in range(1, len(features) + 1):
    print(f"\n[{n_features}/{len(features)}] Testing all {n_features}-feature combinations...")

    n_combos = 0
    best_score_for_n = 0
    best_combo_for_n = None

    # Generate all combinations of n features
    for combo in combinations(range(len(features)), n_features):
        feature_indices = list(combo)

        # Get subset of features
        X_train_subset = X_train_scaled[:, feature_indices]
        X_test_subset = X_test_scaled[:, feature_indices]

        # Train logistic regression
        lr = LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')

        # Use cross-validation score on training set
        cv_scores = cross_val_score(lr, X_train_subset, y_train, cv=3, scoring='accuracy')
        avg_cv_score = cv_scores.mean()

        # Also get test score
        lr.fit(X_train_subset, y_train)
        test_score = lr.score(X_test_subset, y_test)

        n_combos += 1

        # Track best for this n
        if avg_cv_score > best_score_for_n:
            best_score_for_n = avg_cv_score
            best_combo_for_n = combo

        # Track overall best
        if avg_cv_score > best_score:
            best_score = avg_cv_score
            best_features = combo
            best_n_features = n_features
            best_test_score = test_score

        # Store result
        all_results.append({
            'n_features': n_features,
            'features': [features[i] for i in combo],
            'cv_score': avg_cv_score,
            'test_score': test_score
        })

    print(f"    Evaluated {n_combos} combinations")
    print(f"    Best CV score for {n_features} features: {best_score_for_n:.4f}")
    if best_combo_for_n:
        print(f"    Features: {[features[i] for i in best_combo_for_n]}")
# Out:
# ======================================================================
# EXHAUSTIVE FEATURE SELECTION
# ======================================================================
#
# Starting with 19 features
# Total combinations to evaluate: 524,287
#
# [1/19] Testing all 1-feature combinations...
#     Evaluated 19 combinations
#     Best CV score for 1 features: 0.8333
#     Features: ['barthag']
#
# [2/19] Testing all 2-feature combinations...
#     Evaluated 171 combinations
#     Best CV score for 2 features: 0.8482
#     Features: ['adj_oe', 'adj_de']
#
# [3/19] Testing all 3-feature combinations...
#     Evaluated 969 combinations
#     Best CV score for 3 features: 0.8482
#     Features: ['adj_oe', 'adj_de', '3pr']
#
# [4/19] Testing all 4-feature combinations...
#     Evaluated 3876 combinations
#     Best CV score for 4 features: 0.8512
#     Features: ['adj_oe', 'adj_de', 'drb_pct', 'ftr']
#
# [5/19] Testing all 5-feature combinations...
#     Evaluated 11628 combinations
#     Best CV score for 5 features: 0.8512
#     Features: ['wab', 'adj_oe', 'adj_de', 'tor', 'orb_pct']
#
# [6/19] Testing all 6-feature combinations...
#     Evaluated 27132 combinations
#     Best CV score for 6 features: 0.8512
#     Features: ['barthag', 'adj_oe', 'adj_de', '3pr', '3prd', 'adj_tempo']
#
# [7/19] Testing all 7-feature combinations...
#     Evaluated 50388 combinations
#     Best CV score for 7 features: 0.8542
#     Features: ['barthag', 'adj_oe', 'adj_de', 'orb_pct', 'drb_pct', 'ftr', '2p_pct']
#
# [8/19] Testing all 8-feature combinations...
#     Evaluated 75582 combinations
#     Best CV score for 8 features: 0.8512
#     Features: ['adj_oe', 'adj_de', 'drb_pct', 'ftrd', '2p_pct', '3pr', '3prd', 'adj_tempo']
#
# [9/19] Testing all 9-feature combinations...
#     Evaluated 92378 combinations
#     Best CV score for 9 features: 0.8512
#     Features: ['barthag', 'adj_oe', 'adj_de', 'tor', 'orb_pct', 'drb_pct', 'ftrd', '3pr', '3prd']
#
# [10/19] Testing all 10-feature combinations...
#     Evaluated 92378 combinations
#     Best CV score for 10 features: 0.8512
#     Features: ['barthag', 'adj_oe', 'adj_de', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '2p_pct', '3pr', '3prd']
#
# [11/19] Testing all 11-feature combinations...
#     Evaluated 75582 combinations
#     Best CV score for 11 features: 0.8482
#     Features: ['barthag', 'adj_oe', 'adj_de', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftrd', '2p_pct', '3pr', '3prd']
#
# [12/19] Testing all 12-feature combinations...
#     Evaluated 50388 combinations
#     Best CV score for 12 features: 0.8452
#     Features: ['wab', 'barthag', 'adj_oe', 'adj_de', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '3pr', '3prd']
#
# [13/19] Testing all 13-feature combinations...
#     Evaluated 27132 combinations
#     Best CV score for 13 features: 0.8452
#     Features: ['wab', 'barthag', 'adj_oe', 'adj_de', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '3pr', '3prd', 'adj_tempo']
#
# [14/19] Testing all 14-feature combinations...
#     Evaluated 11628 combinations
#     Best CV score for 14 features: 0.8423
#     Features: ['wab', 'barthag', 'adj_oe', 'adj_de', 'efg_pct', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftr', '2p_pct', '3pr', '3prd', 'adj_tempo']
#
# [15/19] Testing all 15-feature combinations...
#     Evaluated 3876 combinations
#     Best CV score for 15 features: 0.8393
#     Features: ['wab', 'barthag', 'adj_oe', 'adj_de', 'efg_pct', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '2p_pct', '3pr', '3prd', 'adj_tempo']
#
# [16/19] Testing all 16-feature combinations...
#     Evaluated 969 combinations
#     Best CV score for 16 features: 0.8333
#     Features: ['wab', 'barthag', 'adj_oe', 'adj_de', 'efg_pct', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '2p_pct', '3p_pct', '3pr', '3prd', 'adj_tempo']
#
# [17/19] Testing all 17-feature combinations...
#     Evaluated 171 combinations
#     Best CV score for 17 features: 0.8244
#     Features: ['wab', 'barthag', 'adj_oe', 'adj_de', 'efg_pct', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '2p_pct', '2pd_pct', '3p_pct', '3pr', '3prd', 'adj_tempo']
#
# [18/19] Testing all 18-feature combinations...
#     Evaluated 19 combinations
#     Best CV score for 18 features: 0.8095
#     Features: ['wab', 'barthag', 'adj_oe', 'adj_de', 'efg_pct', 'efgd_pct', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '2p_pct', '2pd_pct', '3p_pct', '3pr', '3prd', 'adj_tempo']
#
# [19/19] Testing all 19-feature combinations...
#     Evaluated 1 combinations
#     Best CV score for 19 features: 0.8036
#     Features: ['wab', 'barthag', 'adj_oe', 'adj_de', 'efg_pct', 'efgd_pct', 'tor', 'tord', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '2p_pct', '2pd_pct', '3p_pct', '3pd_pct', '3pr', '3prd', 'adj_tempo']

# %%
# ============================================================================
# BEST RESULTS
# ============================================================================
print("\n" + "="*70)
print("BEST MODEL FOUND")
print("="*70)

best_feature_names = [features[i] for i in best_features]
print(f"\nBest Cross-Validation Score: {best_score:.4f}")
print(f"Test Score: {best_test_score:.4f}")
print(f"Number of Features: {best_n_features}")
print(f"\nFeatures Used:")
for i, feat in enumerate(best_feature_names, 1):
    print(f"  {i:2d}. {feat}")

# Train final model with best features
X_train_best = X_train_scaled[:, list(best_features)]
X_test_best = X_test_scaled[:, list(best_features)]

final_model = LogisticRegression(max_iter=1000, random_state=42, solver='liblinear')
final_model.fit(X_train_best, y_train)

y_train_pred = final_model.predict(X_train_best)
y_test_pred = final_model.predict(X_test_best)

train_acc = accuracy_score(y_train, y_train_pred)
test_acc = accuracy_score(y_test, y_test_pred)

print("\n" + "="*70)
print("FINAL MODEL PERFORMANCE")
print("="*70)
print(f"Train Accuracy: {train_acc:.4f}")
print(f"Test Accuracy:  {test_acc:.4f}")

print("\nTest Set Classification Report:")
print(classification_report(y_test, y_test_pred, target_names=['Loss', 'Win']))

print("\nFeature Coefficients:")
coef_df = pd.DataFrame({
    'feature': best_feature_names,
    'coefficient': final_model.coef_[0]
}).sort_values('coefficient', key=abs, ascending=False)
print(coef_df.to_string(index=False))
# Out:
# ======================================================================
# BEST MODEL FOUND
# ======================================================================
#
# Best Cross-Validation Score: 0.8542
# Test Score: 0.8194
# Number of Features: 7
#
# Features Used:
#    1. barthag
#    2. adj_oe
#    3. adj_de
#    4. orb_pct
#    5. drb_pct
#    6. ftr
#    7. 2p_pct
#
# ======================================================================
# FINAL MODEL PERFORMANCE
# ======================================================================
# Train Accuracy: 0.8542
# Test Accuracy:  0.8194
#
# Test Set Classification Report:
#               precision    recall  f1-score   support
#
#         Loss       0.79      0.86      0.83        72
#          Win       0.85      0.78      0.81        72
#
#     accuracy                           0.82       144
#    macro avg       0.82      0.82      0.82       144
# weighted avg       0.82      0.82      0.82       144
#
#
# Feature Coefficients:
# feature  coefficient
#  adj_oe     1.562201
#  adj_de     1.459736
# barthag     0.640263
# orb_pct     0.254233
# drb_pct     0.187824
#     ftr    -0.029798
#  2p_pct     0.024670

# %%
# ============================================================================
# TOP 10 FEATURE COMBINATIONS BY CV SCORE
# ============================================================================
print("\n" + "="*70)
print("TOP 10 FEATURE COMBINATIONS")
print("="*70)

results_df = pd.DataFrame(all_results)
results_df = results_df.sort_values('cv_score', ascending=False)

print("\nTop 10 by Cross-Validation Score:")
for i, row in results_df.head(10).iterrows():
    print(f"\n{results_df.index.get_loc(i) + 1}. CV Score: {row['cv_score']:.4f}, Test Score: {row['test_score']:.4f}, {row['n_features']} features")
    print(f"   Features: {row['features']}")
# Out:
# ======================================================================
# TOP 10 FEATURE COMBINATIONS
# ======================================================================
#
# Top 10 by Cross-Validation Score:
#
# 1. CV Score: 0.8542, Test Score: 0.8194, 7 features
#    Features: ['barthag', 'adj_oe', 'adj_de', 'orb_pct', 'drb_pct', 'ftr', '2p_pct']
#
# 2. CV Score: 0.8512, Test Score: 0.8194, 6 features
#    Features: ['adj_oe', 'adj_de', 'orb_pct', 'drb_pct', '3pr', 'adj_tempo']
#
# 3. CV Score: 0.8512, Test Score: 0.8264, 4 features
#    Features: ['adj_oe', 'adj_de', 'drb_pct', 'ftr']
#
# 4. CV Score: 0.8512, Test Score: 0.8194, 8 features
#    Features: ['adj_oe', 'adj_de', 'drb_pct', 'ftrd', '2p_pct', '3pr', '3prd', 'adj_tempo']
#
# 5. CV Score: 0.8512, Test Score: 0.7917, 6 features
#    Features: ['barthag', 'adj_oe', 'adj_de', '3pr', '3prd', 'adj_tempo']
#
# 6. CV Score: 0.8512, Test Score: 0.8264, 5 features
#    Features: ['adj_oe', 'adj_de', 'drb_pct', 'ftr', 'ftrd']
#
# 7. CV Score: 0.8512, Test Score: 0.8056, 5 features
#    Features: ['wab', 'adj_oe', 'adj_de', 'tor', 'orb_pct']
#
# 8. CV Score: 0.8512, Test Score: 0.8264, 5 features
#    Features: ['barthag', 'adj_oe', 'adj_de', 'drb_pct', 'ftr']
#
# 9. CV Score: 0.8512, Test Score: 0.8194, 10 features
#    Features: ['barthag', 'adj_oe', 'adj_de', 'orb_pct', 'drb_pct', 'ftr', 'ftrd', '2p_pct', '3pr', '3prd']
#
# 10. CV Score: 0.8512, Test Score: 0.8194, 7 features
#    Features: ['adj_oe', 'adj_de', 'orb_pct', 'drb_pct', '2p_pct', '3pr', 'adj_tempo']

# %%
# ============================================================================
# SAVE RESULTS
# ============================================================================
print("\n" + "="*70)
print("SAVING RESULTS")
print("="*70)

# Save best model
with open('best_exhaustive_model.pkl', 'wb') as f:
    pickle.dump(final_model, f)
print("✓ Model saved: best_exhaustive_model.pkl")

# Save scaler
with open('exhaustive_scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("✓ Scaler saved: exhaustive_scaler.pkl")

# Save best features
with open('best_features.txt', 'w') as f:
    f.write("Best Features from Exhaustive Search\n")
    f.write("="*70 + "\n\n")
    f.write(f"CV Score: {best_score:.4f}\n")
    f.write(f"Test Score: {best_test_score:.4f}\n")
    f.write(f"Number of Features: {best_n_features}\n\n")
    f.write("Features:\n")
    for feat in best_feature_names:
        f.write(f"  - {feat}\n")
print("✓ Best features saved: best_features.txt")

# Save all results
results_df.to_csv('exhaustive_search_results.csv', index=False)
print("✓ All results saved: exhaustive_search_results.csv")

print("\n" + "="*70)
print("EXHAUSTIVE SEARCH COMPLETE!")
print("="*70)
# Out:
# ======================================================================
# SAVING RESULTS
# ======================================================================
# ✓ Model saved: best_exhaustive_model.pkl
# ✓ Scaler saved: exhaustive_scaler.pkl
# ✓ Best features saved: best_features.txt
# ✓ All results saved: exhaustive_search_results.csv
#
# ======================================================================
# EXHAUSTIVE SEARCH COMPLETE!
# ======================================================================
